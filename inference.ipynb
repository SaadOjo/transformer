# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from celeba_dataset import CelebADataset
from pympler import asizeof
from saad_face import SaadFace
from tqdm import tqdm
import torch.nn.functional as F

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
dataset = CelebADataset(img_dir='./data/celeba/img_align_celeba', label_file='./data/celeba/identity_CelebA.txt', transform=transform, type='embedding_gen')
embedding_generation_dataloader = torch.utils.data.DataLoader(dataset, batch_size=1)

train_dataset = CelebADataset(img_dir='./data/celeba/img_align_celeba', label_file='./data/celeba/identity_CelebA.txt', transform=transform, type='train')
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=1)

model = SaadFace(embedding_dim=128)
model.load_state_dict(torch.load('models/model.pth', map_location=device))
model.to(device)
model.eval()

# %%
# Generate a dictionary with the average embeddings for each identity
identity_embeddings = {}
for image_tensor, label in tqdm(embedding_generation_dataloader):
    image_tensor = torch.squeeze(image_tensor, 0)
    embedding = torch.mean(model(image_tensor.to(device)), axis=0)
    embedding = embedding.cpu().detach()
    identity_embeddings[label[0]] = embedding
# Out:
# 100%|██████████| 5641/5641 [01:58<00:00, 47.62it/s]

# %%
embedding_labels = list(identity_embeddings.keys())
embeddings_matrix = torch.stack(list(identity_embeddings.values()))

# %%
len(embedding_labels)
# Out:
# 5641

# %%
def find_nearest_label(input_vector: torch.Tensor):
    # Compute cosine similarity in batch
    similarities = F.cosine_similarity(input_vector.unsqueeze(0), embeddings_matrix)
    
    # Find the maximum similarity
    max_index = torch.argmax(similarities)
    nearest_label = embedding_labels[max_index]
    max_similarity = similarities[max_index].item()
    
    return nearest_label, max_similarity

# %%
def find_nearest_label_euclidean(input_vector: torch.Tensor):

    # Compute Euclidean distance in batch
    distances = torch.norm(embeddings_matrix - input_vector.unsqueeze(0), dim=1)

    # Find the minimum distance
    min_index = torch.argmin(distances)
    nearest_label = embedding_labels[min_index]
    min_distance = distances[min_index].item()

    return nearest_label, min_distance

# %%
dataiter = iter(train_dataloader)
distance_method = 'euclidean'
for images, labels in dataiter:
    image = images
    label = labels[0]
    embedding = model(image.to(device))
    embedding = embedding.cpu().detach()
    embedding = torch.squeeze(embedding, 0)
    if distance_method == 'cosine':
        nearest_label, similarity = find_nearest_label(embedding)
        print(f"True label: {label}, Nearest label: {nearest_label}, Similarity: {similarity}")
    elif distance_method == 'euclidean':
        nearest_label, distance = find_nearest_label_euclidean(embedding)
        print(f"True label: {label}, Nearest label: {nearest_label}, Similarity: {distance}")
# Out:
# True label: 6322, Nearest label: 1050, Similarity: 0.008085524663329124
# True label: 6322, Nearest label: 9373, Similarity: 0.013651452027261257
# True label: 6322, Nearest label: 1050, Similarity: 0.04406757280230522
# True label: 6322, Nearest label: 7178, Similarity: 0.009626053273677826
# True label: 6322, Nearest label: 10061, Similarity: 0.012456787750124931
# True label: 1849, Nearest label: 3319, Similarity: 0.04280870035290718
# True label: 1849, Nearest label: 2998, Similarity: 0.02322578988969326
# True label: 1849, Nearest label: 8581, Similarity: 0.02117781899869442
# True label: 1231, Nearest label: 3041, Similarity: 0.029993848875164986
# True label: 1231, Nearest label: 6871, Similarity: 0.01548078004270792
# True label: 8826, Nearest label: 6645, Similarity: 0.024024723097682
# True label: 8826, Nearest label: 2089, Similarity: 0.014632211066782475
# True label: 8826, Nearest label: 1127, Similarity: 0.024985607713460922
# True label: 303, Nearest label: 7875, Similarity: 0.04434208944439888
# True label: 303, Nearest label: 8529, Similarity: 0.008272414095699787
# True label: 303, Nearest label: 3948, Similarity: 0.010323782451450825
# True label: 5165, Nearest label: 1962, Similarity: 0.016787739470601082
# True label: 5165, Nearest label: 7775, Similarity: 0.008703320287168026
# True label: 5165, Nearest label: 46, Similarity: 0.028399858623743057
# True label: 5165, Nearest label: 2463, Similarity: 0.015176291577517986
# True label: 5165, Nearest label: 1033, Similarity: 0.025604205206036568
# True label: 2466, Nearest label: 7158, Similarity: 0.019552482292056084
# True label: 2466, Nearest label: 5848, Similarity: 0.01535598561167717
# True label: 2466, Nearest label: 587, Similarity: 0.024973751977086067
# True label: 2466, Nearest label: 8825, Similarity: 0.01759612001478672
# True label: 2466, Nearest label: 865, Similarity: 0.011591032147407532
# True label: 2466, Nearest label: 1531, Similarity: 0.013906477950513363
# True label: 2466, Nearest label: 2935, Similarity: 0.02812206745147705
# True label: 8557, Nearest label: 2152, Similarity: 0.10038868337869644
# True label: 8557, Nearest label: 5432, Similarity: 0.06469450891017914
# True label: 8343, Nearest label: 9597, Similarity: 0.00952790305018425
# True label: 8343, Nearest label: 1503, Similarity: 0.09287824481725693
# True label: 8343, Nearest label: 7519, Similarity: 0.013626272790133953
# True label: 8343, Nearest label: 4786, Similarity: 0.01989760249853134
# True label: 8343, Nearest label: 2479, Similarity: 0.01762627251446247
# True label: 1996, Nearest label: 1033, Similarity: 0.04612864926457405
# True label: 1996, Nearest label: 2260, Similarity: 0.013646506704390049
# True label: 1385, Nearest label: 2341, Similarity: 0.007297468837350607
# True label: 1385, Nearest label: 1385, Similarity: 0.022617576643824577
# True label: 1385, Nearest label: 6749, Similarity: 0.01771077699959278
# True label: 1385, Nearest label: 3128, Similarity: 0.10485759377479553
# True label: 1385, Nearest label: 9010, Similarity: 0.0284564308822155
# True label: 5668, Nearest label: 6877, Similarity: 0.014743701554834843
# True label: 5668, Nearest label: 9098, Similarity: 0.05447270721197128
# True label: 5668, Nearest label: 3306, Similarity: 0.019759714603424072
# True label: 10039, Nearest label: 5169, Similarity: 0.024670762941241264
# True label: 10039, Nearest label: 2448, Similarity: 0.0559493787586689
# True label: 10039, Nearest label: 1136, Similarity: 0.07440812140703201
# True label: 10039, Nearest label: 9758, Similarity: 0.014394441619515419
# True label: 1711, Nearest label: 7510, Similarity: 0.05623890459537506
# True label: 1711, Nearest label: 2156, Similarity: 0.12403813004493713
# True label: 1711, Nearest label: 7220, Similarity: 0.04437477886676788
# True label: 1711, Nearest label: 7756, Similarity: 0.12497417628765106
# True label: 5960, Nearest label: 2638, Similarity: 0.04391898959875107
# True label: 5960, Nearest label: 4306, Similarity: 0.04354454576969147
# True label: 5960, Nearest label: 549, Similarity: 0.0359930694103241
# True label: 8, Nearest label: 9585, Similarity: 0.028434090316295624
# True label: 8, Nearest label: 6419, Similarity: 0.012599177658557892
# True label: 8, Nearest label: 155, Similarity: 0.033058516681194305
# True label: 839, Nearest label: 2156, Similarity: 0.14792685210704803
# True label: 839, Nearest label: 145, Similarity: 0.05728740617632866
# True label: 839, Nearest label: 6494, Similarity: 0.04896485432982445
# True label: 1415, Nearest label: 4120, Similarity: 0.021899666637182236
# True label: 6311, Nearest label: 562, Similarity: 0.13030056655406952
# True label: 1173, Nearest label: 3555, Similarity: 0.03148559108376503
# True label: 1173, Nearest label: 6792, Similarity: 0.014442174695432186
# True label: 1173, Nearest label: 2775, Similarity: 0.038105111569166183
# True label: 1390, Nearest label: 3513, Similarity: 0.005969211924821138
# True label: 1390, Nearest label: 5445, Similarity: 0.012115509249269962
# True label: 1390, Nearest label: 5949, Similarity: 0.0729299858212471
# True label: 5581, Nearest label: 438, Similarity: 0.04025963321328163
# True label: 5581, Nearest label: 3028, Similarity: 0.009177948348224163
# True label: 1572, Nearest label: 6147, Similarity: 0.014678525738418102
# True label: 1572, Nearest label: 8091, Similarity: 0.018914364278316498
# True label: 1572, Nearest label: 6941, Similarity: 0.014835255220532417
# True label: 1572, Nearest label: 665, Similarity: 0.021643556654453278
# True label: 7676, Nearest label: 4607, Similarity: 0.01623459719121456
# True label: 7676, Nearest label: 2660, Similarity: 0.033683668822050095
# True label: 7676, Nearest label: 922, Similarity: 0.04319845885038376
# True label: 7676, Nearest label: 6430, Similarity: 0.025233369320631027
# True label: 5549, Nearest label: 8833, Similarity: 0.03698178753256798
# True label: 5549, Nearest label: 9165, Similarity: 0.03625769540667534
# True label: 5549, Nearest label: 3026, Similarity: 0.026956966146826744
# True label: 5549, Nearest label: 480, Similarity: 0.03817035257816315
# True label: 5549, Nearest label: 2890, Similarity: 0.024898316711187363
# True label: 4367, Nearest label: 3950, Similarity: 0.03052724525332451
# True label: 4367, Nearest label: 8273, Similarity: 0.01717638596892357
# True label: 4367, Nearest label: 5898, Similarity: 0.010023407638072968
# True label: 4367, Nearest label: 5951, Similarity: 0.020553698763251305
# True label: 4367, Nearest label: 6483, Similarity: 0.032117243856191635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 6
#       4 image = images
#       5 label = labels[0]
# ----> 6 embedding = model(image.to(device))
#       7 embedding = embedding.cpu().detach()
#       8 embedding = torch.squeeze(embedding, 0)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/transformer/saad_face.py:12, in SaadFace.forward(self, x)
#      11 def forward(self, x):
# ---> 12     x = self.model(x)
#      13     return nn.functional.normalize(x, p=2, dim=1)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torchvision/models/mobilenetv3.py:220, in MobileNetV3.forward(self, x)
#     219 def forward(self, x: Tensor) -> Tensor:
# --> 220     return self._forward_impl(x)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torchvision/models/mobilenetv3.py:210, in MobileNetV3._forward_impl(self, x)
#     209 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 210     x = self.features(x)
#     212     x = self.avgpool(x)
#     213     x = torch.flatten(x, 1)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torchvision/models/mobilenetv3.py:111, in InvertedResidual.forward(self, input)
#     110 def forward(self, input: Tensor) -> Tensor:
# --> 111     result = self.block(input)
#     112     if self.use_res_connect:
#     113         result += input
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/modules/activation.py:488, in Hardswish.forward(self, input)
#     487 def forward(self, input: Tensor) -> Tensor:
# --> 488     return F.hardswish(input, self.inplace)
#
# File /opt/miniconda3/envs/transformer/lib/python3.10/site-packages/torch/nn/functional.py:2149, in hardswish(input, inplace)
#    2147     return handle_torch_function(hardswish, (input,), input, inplace=inplace)
#    2148 if inplace:
# -> 2149     return torch._C._nn.hardswish_(input)
#    2150 return torch._C._nn.hardswish(input)
#
# KeyboardInterrupt:
